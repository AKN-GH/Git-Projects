# %% [markdown]
# <a href="https://colab.research.google.com/github/AKN-GH/Git-Projects/blob/main/Exercise2(31_10_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задача 3

# %%
total_minutes = 135
hours = total_minutes // 60
minutes = total_minutes % 60
print (f'hours = {hours} \nminutes = {minutes}')
# Out:
# hours = 2
# minutes = 15

# %% [markdown]
# Задача 5

# %%
cal_tot = 0.719
rep_tot = 0.719
epsilon = 1e-9
is_equal_price = abs(cal_tot - rep_tot) < epsilon
print (f'calculated_total = {cal_tot} \nreported_total = {rep_tot} \nis_equal_price = {is_equal_price}')

# %% [markdown]
# Задача 7

# %%
numbers = []  # Список для хранения введённых чисел
total_sum = 0  # Переменная для суммы чисел
while True:
    num = int(input())  # Считываем число из консоли
    numbers.append(num)
    total_sum += num
    # Проверяем, если сумма стала равной 0
    if total_sum == 0:
        break
# Вычисляем сумму квадратов
sum_of_squares = sum(x ** 2 for x in numbers)

# Выводим результат
print(sum_of_squares)

# %% [markdown]
# Задача 8

# %%
n = int(input())
result = []
current_num = 1
while len(result) < n:
    for _ in range(current_num):
        if len(result) < n:
            result.append(current_num)
    current_num += 1

print(*result)

# %% [markdown]
# Задача 10

# %%
A = [1, 2, 3, 4, 2, 1, 3, 4, 5, 6, 5, 4, 3, 2]
B = ['a', 'b', 'c', 'c', 'c', 'b', 'a', 'c', 'a', 'a', 'b', 'c', 'b', 'a']

result = {}
for key, value in zip(B, A):
    result[key] = result.get(key, 0) + value
print(result)
