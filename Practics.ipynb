# %% [markdown]
# <a href="https://colab.research.google.com/github/AKN-GH/Git-Projects/blob/main/Practics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Практическое занятие № 1 от 31.10.2025**

# %% [markdown]
# Задание 1

# %%
print ('Hello World')
# Out:
# Hello World

# %% [markdown]
# Задание 2

# %%
print ('4','8','15','16','23','42' )
# Out:
# 4 8 15 16 23 42

# %% [markdown]
# Задание 3

# %%
print ('*','**','***','****','*****','******','*******',sep='\n')
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %% [markdown]
# Задание
#  4

# %%
print ('Отчёт о доходах:', '1 квартал: 1200000 руб.','2 квартал: 1350000 руб.','3 квартал: 1280000 руб.','4 квартал: 1420000 руб.', sep='\n')
# Out:
# Отчёт о доходах:
# 1 квартал: 1200000 руб.
# 2 квартал: 1350000 руб.
# 3 квартал: 1280000 руб.
# 4 квартал: 1420000 руб.

# %% [markdown]
# Задание 5

# %%
analytics_name = input('Введите имя аналитика:')
print (f'Добро пожаловать в команду, {analytics_name}!')
# Out:
# Введите имя аналитика:Влад
# Добро пожаловать в команду, Влад!

# %% [markdown]
# Задание 6

# %%
company_name = input ('Введите название компании:')
print (f'{company_name} - лидер рынка!' )
# Out:
# Введите название компании:Сбер
# Сбер - лидер рынка!

# %% [markdown]
# Задание 7

# %%
dataset_name = input('Введите название набора данных:')
raw_count = input('Введите количество строк:')
number_of_colums = input('Введите число столбцов:')
print (dataset_name, raw_count, number_of_colums, sep='\n')
# Out:
# Введите название набора данных:Sales Q1
# Введите количество строк:1000
# Введите число столбцов:8
# Sales Q1
# 1000
# 8

# %% [markdown]
# Задание 8

# %%
list_1 = input()
list_2 = input()
list_3 = input()
print (list_3, list_2, list_1, sep='\n')
# Out:
# Продажи за январь
# Продажи за февраль
# Продажи за март
# Продажи за март
# Продажи за февраль
# Продажи за январь

# %% [markdown]
# Задание 9

# %%
base_price = float(input('Введите базовую цену:'))
grows_percent = float(input('Введите процент прироста цены:'))
new_price = base_price*(1+grows_percent/100)
delta = new_price-base_price
print ('new_price =',new_price)
print ('delta =',delta)
# Out:
# Введите базовую цену:100
# Введите процент прироста цены:20
# new_price = 120.0
# delta = 20.0

# %% [markdown]
# Задание 10

# %%
print ('Северный', 'Центральный', 'Южный', sep='***')
# Out:
# Северный***Центральный***Южный

# %% [markdown]
#  Задание 11

# %%
analytics_name = input('Введите имя аналитика:')
print ("Подключение установлено. Добро пожаловать,", analytics_name, end='!')
# Out:
# Введите имя аналитика:Влад
# Подключение установлено. Добро пожаловать, Влад!

# %% [markdown]
# Задание 12

# %%
symbol_s = input('Введите разделитель символ-разделитель:')
product_1 = input('Введите название Товара 1:')
product_2 = input('Введите название Товара 2:')
product_3 = input('Введите название Товара 3:')
print (product_1, end=symbol_s)
print (product_2, end=symbol_s)
print (product_3, end=symbol_s)
# Out:
# Введите разделитель символ-разделитель:|
# Введите название Товара 1:Молоко
# Введите название Товара 2:Хлеб
# Введите название Товара 3:Сыр
# Молоко|Хлеб|Сыр|

# %% [markdown]
# Задание 13

# %%
value_str = float(input('Введите значение:'))
value_str = int(value_str)
print (f'integer_part = {value_str}')
# Out:
# Введите значение:42.7
# integer_part = 42

# %% [markdown]
# Задание 14

# %%
orders_yesterday = int(input('Введите количество заказов предыдущего дня:'))
plan = int(input('Введите плановый показатель:'))
abs_diff = abs(orders_yesterday-plan)
print (f'Абсолютное отклонение от плана равняется {abs_diff}')
# Out:
# Введите количество заказов предыдущего дня:10
# Введите плановый показатель:20
# Абсолютное отклонение от плана равняется 10

# %% [markdown]
# Задание 15

# %%
dig_1 = int(input('Введите целое число #1:'))
dig_2 = int(input('Введите целое число #2:'))
dig_3 = int(input('Введите целое число #3:'))
dig_4 = int(input('Введите целое число #4:'))
dig_5 = int(input('Введите целое число #5:'))
digitsline = [dig_1, dig_2, dig_3, dig_4, dig_5]
max_dig = max(digitsline)
min_dig = min(digitsline)
print ('Наименьшее число =', min_dig)
print ('Наибольшее число =', max_dig)
# Out:
# Введите целое число #1
# 1
# Введите целое число #2
# 2
# Введите целое число #3
# 3
# Введите целое число #4
# 4
# Введите целое число #5
# 5
# Наименьшее число = 1
# Наибольшее число = 5

# %% [markdown]
# Задание 16

# %%
name = str(input('Введите имя пользователя:'))
surname = str(input('Введите фамилию пользователя:'))
s = str('!')
print ('Привет,',name+' '+surname+s,'Вы только что начали изучать Python')
# Out:
# Введите имя пользователя:Антон
# Введите фамилию пользователя:Иванов
# Привет, Антон Иванов! Вы только что начали изучать Python

# %% [markdown]
# Задание 17

# %%
fh_ph = str(input('Введите первую половину фразы:'))
sh_ph = str(input('Введите вторую половину фразы:'))
b = str('"')
s = str(', ')
d = str('.')
print (b+fh_ph+s+sh_ph+d+b)
# Out:
# Введите первую половину фразы:Каждый в этой стране должен научиться программировать
# Введите вторую половину фразы:потому что это учит думать
# "Каждый в этой стране должен научиться программировать, потому что это учит думать."

# %% [markdown]
# Задание 18

# %%
inp = float(input('Введите сумму покупки в рублях:'))
print (inp>1000)
# Out:
# Введите сумму покупки в рублях:999
# False

# %% [markdown]
# Задание 19

# %%
age = int(input('Введите возраст полных лет:'))
print (age>=18)
# Out:
# Введите возраст полных лет:16
# False

# %% [markdown]
# Задание 20

# %%
s = float(input('Введите объем данных между потоками (МБ):'))
v_1 = float(input('Введите скорость первого потока (МБ/ч):'))
v_2 = float(input('Введите скорость второго потока (МБ/ч):'))
t = s/(v_1+v_2)
print (f'Потоки достигнут одного и того же объёма данных через {t} часов')
# Out:
# Введите объем данных между потоками (МБ):500
# Введите скорость первого потока (МБ/ч):50
# Введите скорость второго потока (МБ/ч):70
# Потоки достигнут одного и того же объёма данных через 4.166666666666667 часов

# %% [markdown]
# Задание 21

# %%
a = float(input('Введите длину первого катета (мм):'))
b = float(input('Введите длину второго катета (мм):'))
s = (a*b)/2
print (f'Площадь треугольника = {s} мм')
# Out:
# Введите длину первого катета (мм):443
# Введите длину второго катета (мм):390
# Площадь треугольника = 86385.0 мм

# %% [markdown]
# Задание 22

# %%
t_f = float(input('Введите температуру в градусах по шкале Фаренгейта:'))
t_c = 5/9*(t_f-32)
print (f'Температура в градусах по шкале Цельсия = {t_c}')
# Out:
# Введите температуру в градусах по шкале Фаренгейта:450.55
# Температура в градусах по шкале Цельсия = 232.5277777777778

# %% [markdown]
# Задание 23

# %%
revenue_str = float(input('Введите выручку за день:'))
revenue_str = revenue_str//1
courier_name = str(input('Введите имя курьера:'))
report = int(revenue_str*0.01//1) # //1 на случай изменния процена и возможности появления дробной части
print (f'Курьер {courier_name} получит бонус {report} р.')
# Out:
# Введите выручку за день:438746.78
# Введите имя курьера:Антон
# Курьер Антон получит бонус 4387 р.

# %% [markdown]
# **Практическое занятие № 2 от 05.11.2025**

# %% [markdown]
# Задание 1

# %%
pass1 = input('Введите пароль:')
pass2 = input('Введите пароль еще раз:')
if pass1 == 'qwerty' and pass2 == 'qwerty':
    print ('Пароль принят')
else:
    print ('Пароль не принят')
# Out:
# Введите пароль:qwerty
# Введите пароль еще раз:Qwerty
# Пароль не принят

# %% [markdown]
# Задание 2

# %%
uage = int(input('Введите возраст пользователя:'))
if uage  >= 18:
    print ('Доступ разрешен')
else:
    print ('Доступ запрещен')
# Out:
# Введите возраст пользователя:18
# Доступ разрешен

# %% [markdown]
# Задание 3
